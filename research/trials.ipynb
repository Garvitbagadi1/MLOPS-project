# %%
d = {"key":"value", "kay1":"value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key3":"value", "kay4":"value1"})

# %%
d2.key3
# Out:
# 'value'

# %%
def get_profit(x:int,y:int)->int:
    return x*y;

# %%
get_profit(x=2,y="5")
# Out:
# '55'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_profit(x:int, y:int)->int:
    return x*y;

# %%
get_profit(x=5,y=6)
# Out:
# 30
